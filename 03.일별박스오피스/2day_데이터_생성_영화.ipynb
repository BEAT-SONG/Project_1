# %%
key_API : 8b5e4d28da95d1d2b044f932bc052ef6
key_API_2 : f624d0b316bc92def01c578a8fd5947e
김예은_1 : 85af968eda791f7a469d4826054ab040
김예은_2 : db34324ef66ec08e25d5fb7ca93bea96
김광조_1 : 1f84ed9279086ccfa21c6ef005b89a5f
김광조_2 : b96b0340ed3c91bd9e4a5ce4d0534fa3
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_7252/3880370153.py", line 1
#     key_API : 8b5e4d28da95d1d2b044f932bc052ef6
#                ^
# SyntaxError: invalid syntax

# %%
from datetime import datetime, timedelta
import requests
import json
import pandas as pd

# 날짜를 문자열로 변환하는 함수
def date_string(date):
    date_list = str(date).split()[0].split('-')
    date_str = date_list[0]+date_list[1]+date_list[2]
    return date_str

yourkey='f624d0b316bc92def01c578a8fd5947e' #((키 넣어주시면 됩니다!))

#원하는 날짜 +1 해주세요. 2018년 전체를 하고싶다면 (2019,1,1) ((날짜 수정해주시면 됩니다!))
date = datetime(2013,1,1)
date_str = date_string(date)
print(date_str)

movie_list = []

# 2018년 1월1일까지만 할것이다 ((날짜 수정해주시면 됩니다!))
while date_str != '20120101':
    date = date - timedelta(days=1)
    date_str = date_string(date)
    # print(date_str)

    url = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key='+yourkey+'&targetDt='+date_str
    res = requests.get(url)
    text= res.text

    d = json.loads(text)

    x=d['boxOfficeResult']['showRange'] #박스오피스 일자 추출

    for b in d['boxOfficeResult']['dailyBoxOfficeList']:
        
        movie_list.append([x,b['rank'],
                           b['rankInten'],
                           b['rankOldAndNew'],
                           b['movieCd'],
                           b['movieNm'],
                           b['openDt'],
                           b['salesAmt'],
                           b['salesShare'],
                           b['salesInten'],
                           b['salesChange'],
                           b['salesAcc'],
                           b['audiCnt'],
                           b['audiInten'],
                           b['audiChange'],
                           b['audiAcc'],
                           b['scrnCnt'],
                           b['showCnt']])
    # rnum은 순번을 출력하는 것이기 때문에 안넣었습니다

    # 파일 이름 변경하는 곳 ((파일이름 수정해주시면 됩니다!))
data = pd.DataFrame(movie_list, columns = ['일자','순위',
                               '순위 증감분', 
                               '신규진입여부',
                               '대표코드',
                               '영화명(국문)',
                               '개봉일',
                               '매출액',
                               '매출총액 대비 매출비율',
                               '전일 대비 매출액 증감분',
                               '전일 대비 매출액 증감비율',
                               '누적매출액',
                               '관객수',
                               '전일 대비 관객수 증감분',
                               '전일 대비 관객수 증감 비율',
                               '누적관객수',
                               '상영 스크린 수',
                               '상영 횟수'])
data.to_csv("./real_data/2012_movie_day.csv", mode='a', encoding='utf-8', index=False)
# Out:
# 20130101

# %%
# 파일 경로 지정
file_path = "./real_data/2012_movie_day.csv"

# 파일을 읽어 들여서 Data Frame 형태로 읽어들이기
# pd뒤에 .을 '접근인자'라고 함
df_csv = pd.read_csv(file_path)

df_csv
# Out:
#                      일자  순위  순위 증감분 신규진입여부      대표코드  \
# 0     20121231~20121231   1       0    OLD  20124039
# 1     20121231~20121231   2       0    OLD  20128274
# 2     20121231~20121231   3       0    OLD  20124399
# 3     20121231~20121231   4       0    OLD  20125048
# 4     20121231~20121231   5       0    OLD  20128687
# ...                 ...  ..     ...    ...       ...
# 3655  20120101~20120101   6       1    OLD  19940256
# 3656  20120101~20120101   7      -1    OLD  20113381
# 3657  20120101~20120101   8       0    OLD  20112709
# 3658  20120101~20120101   9       0    OLD  20113311
# 3659  20120101~20120101  10       0    OLD  20112708
#
#                                   영화명(국문)         개봉일         매출액  \
# 0                                      타워  2012-12-25  2255715500
# 1                                   레미제라블  2012-12-19  1791446500
# 2                                     반창꼬  2012-12-19   938697500
# ...

# %%
   x=d['boxOfficeResult']['showRange']
