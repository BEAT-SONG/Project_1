# %% [markdown]
# ## 극한직업 워드클라우드

# %%
# from wordcloud import WordCloud
# from konlpy.tag import Twitter
# from collections import Counter

# # open으로 txt파일을 열고 read()를 이용하여 읽는다.
# text = open('jobofhell.txt').read() 


# twitter = Twitter()

# # twitter함수를 통해 읽어들인 내용의 형태소를 분석한다.
# sentences_tag = []
# sentences_tag = twitter.pos(text) 

# noun_adj_list = []


# # tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
# for word, tag in sentences_tag:
#     if tag in ['Noun' , 'Adjective']: 
#         noun_adj_list.append(word)


# # 가장 많이 나온 단어부터 40개를 저장한다.
# counts = Counter(noun_adj_list)
# tags = counts.most_common(40) 


# # WordCloud를 생성한다.
# # 한글을 분석하기위해 font를 한글로 지정해주어야 된다. macOS는 .otf , window는 .ttf 파일의 위치를
# # 지정해준다. (ex. '/Font/GodoM.otf')
# wc = WordCloud(font_path=['./'],background_color="white", max_font_size=60)
# cloud = wc.generate_from_frequencies(dict(tags))


# # 생성된 WordCloud를 test.jpg로 보낸다.
# cloud.to_file('test.jpg')

# %%
# from wordcloud import WordCloud
# from konlpy.tag import Twitter
# from collections import Counter

# %%
# text = open('jobofhell.txt').read()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/jobofhell.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/극한직업_워드클라우드.png')

# %% [markdown]
# # 국제시장 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/international_market.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/국제시장_워드클라우드.png')

# %% [markdown]
# # 도둑들 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/thieves.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
#딕셔너리 값 삭제
del c['정도']
c
# Out:
# Counter({'스토리': 1597,
#          '연기자': 1597,
#          '연기': 3194,
#          '누구': 1597,
#          '하나': 1597,
#          '별로': 3194,
#          '평타': 1597,
#          '전지현': 4791,
#          '매력': 1597,
#          '다시': 1597,
#          '영화': 4791,
#          '웨이홍': 1597,
#          '캐스팅': 1597,
#          '투자': 1597,
#          '사기꾼': 1597,
#          '제목': 1597,
#          '계속': 1597,
#          '통수': 1597,
#          '반전': 1597,
#          '집중': 1597,
#          '오락': 1597,
#          '영화로': 1597,
#          '김윤석': 3194,
#          '액션': 1597,
#          '마음': 1597,
#          '킬링타임': 1597,
#          '제격': 1597,
#          '상업': 1597,
#          '로만': 1597,
#          '부분': 1597,
#          '캐릭터': 1597,
#          '살림': 1597,
#          '김혜수': 1597,
#          '기보': 1597,
#          '재미': 1597,
#          '아따': 1597,
#          '김수현': 1597,
#          '취향': 1597,
#          '임달화': 1597})

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/도둑들_워드클라우드.png')

# %% [markdown]
# # 베테랑 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/veteran.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
#딕셔너리 값 삭제
del c['영화']

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/베테랑_워드클라우드.png')

# %% [markdown]
# # 신과함께 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/with_god.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
#딕셔너리 값 삭제
del c['기대']
c
# Out:
# Counter({'이정재': 5704,
#          '홍보': 5704,
#          '이유': 5704,
#          '관심병사': 5704,
#          '연기': 5704,
#          '남자': 5704,
#          '이서': 5704,
#          '주먹': 5704,
#          '입틀막함': 5704,
#          '여보': 5704,
#          '이번': 5704,
#          '겨울': 5704,
#          '부모님': 5704,
#          '밥솥': 5704,
#          '가족': 5704,
#          '우리': 5704,
#          '아빠': 5704,
#          '처음': 5704,
#          '대한민국': 5704,
#          '자홍': 5704,
#          '홍씨': 5704,
#          '응원': 5704,
#          '화장': 5704,
#          '신의한수': 5704,
#          '생각': 5704,
#          '볼거리': 5704,
#          '스토리': 5704,
#          '캐릭터': 5704,
#          '케미': 5704,
#          '모두': 5704,
#          '이상': 5704,
#          '이정': 5704,
#          '감동': 5704,
#          '도대체': 5704,
#          '지은': 5704,
#          '몇개': 5704,
#          '장르': 5704,
#          '판타지': 5704,
#          '정말': 5704,
#          '마지막': 5704,
#          '반전': 5704,
#          '대해': 5704,
# ...

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/신과함께_워드클라우드.png')

# %% [markdown]
# # 7번방의 선물 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/present_of_7.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
del c["영화"]

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/7번방의선물_워드클라우드.png')

# %% [markdown]
# # 아바타 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/avata.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
del c["전개"]

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/아바타_워드클라우드.png')

# %% [markdown]
#  # 명량 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/leesunshin.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
del c["영화"]

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc.to_file('./movie_wordcloud/명량_워드클라우드.png')

# %% [markdown]
# # 택시운전사 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
with open('./movie_comment/taxidriver.txt', 'r') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words)

# %%
del c["영화"]

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)
