# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10452\1864857770.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")

# %%
url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=62266&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
driver.get(url)

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#페이지수 : 4082
coment_list = []

for j in range (1,4083):
    try:
        url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=62266&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={}".format(j)

        html = driver.page_source

        from bs4 import BeautifulSoup
        soup = BeautifulSoup(html, "html.parser")



        for i in range (0,10):
            text = list(soup.select("#_filtered_ment_{}".format(i))[0])[0][64:]
            text_mod = text.replace("\t","")
            text_mod_final = text_mod.replace("\n","")
            
            coment_list.append(text_mod_final)
        
    except :
        pass

# %%
coment_list
# Out:
# ['영화사인 한 획을 그은 영화 ',
#  '스토리 전개 뻔할지도 몰라요 근데 좋음  스토리  전개 보단 나비 행성에서의 판타지 넘치는 일상이 날 설레게 해요 ',
#  '헐리우드가괜히 헐리우드가 아니다.. ',
#  '3D 아이맥스는 진정 최고였다. ',
#  '제임스 카메론 감독 영화는 다 명작인듯 ',
#  '나비행성에서 살고싶을 정도로 매혹적이었던 신세계를 보았음 ',
#  '이거랑 명량이랑 비교하는건;;; 무슨;; 장난하나; ',
#  '',
#  '대체 스토리가 어떻다고 이형석,백승찬 기자는 스토리에 4점을 줬지?아 물론 참신한 이야기는 아니었지만 과연 4점받을 정도로 쓰레기 스토린가?진짜 납득이 안가네 ㄷㄷ ',
#  '감동해서 잠이 안왔던 영화. ',
#  '영화사인 한 획을 그은 영화 ',
#  '스토리 전개 뻔할지도 몰라요 근데 좋음  스토리  전개 보단 나비 행성에서의 판타지 넘치는 일상이 날 설레게 해요 ',
#  '헐리우드가괜히 헐리우드가 아니다.. ',
#  '3D 아이맥스는 진정 최고였다. ',
#  '제임스 카메론 감독 영화는 다 명작인듯 ',
#  '나비행성에서 살고싶을 정도로 매혹적이었던 신세계를 보았음 ',
#  '이거랑 명량이랑 비교하는건;;; 무슨;; 장난하나; ',
#  '',
#  '대체 스토리가 어떻다고 이형석,백승찬 기자는 스토리에 4점을 줬지?아 물론 참신한 이야기는 아니었지만 과연 4점받을 정도로 쓰레기 스토린가?진짜 납득이 안가네 ㄷㄷ ',
#  '감동해서 잠이 안왔던 영화. ',
#  '영화사인 한 획을 그은 영화 ',
#  '스토리 전개 뻔할지도 몰라요 근데 좋음  스토리  전개 보단 나비 행성에서의 판타지 넘치는 일상이 날 설레게 해요 ',
#  '헐리우드가괜히 헐리우드가 아니다.. ',
#  '3D 아이맥스는 진정 최고였다. ',
#  '제임스 카메론 감독 영화는 다 명작인듯 ',
#  '나비행성에서 살고싶을 정도로 매혹적이었던 신세계를 보았음 ',
# ...

# %%
#저장
import csv

with open('./movie_comment/avata.txt', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(coment_list)
