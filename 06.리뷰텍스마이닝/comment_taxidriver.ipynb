# %%
from selenium import webdriver

driver = webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")

url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=146469&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
driver.get(url)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13672\1710923404.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/ChromeDriver/chromedriver.exe")

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#페이지수 : 4888
coment_list = []

for j in range (1,4889):
    try:
        url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=146469&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={}".format(j)

        html = driver.page_source

        from bs4 import BeautifulSoup
        soup = BeautifulSoup(html, "html.parser")



        for i in range (0,10):
            text = list(soup.select("#_filtered_ment_{}".format(i))[0])[0][64:]
            text_mod = text.replace("\t","")
            text_mod_final = text_mod.replace("\n","")
            
            coment_list.append(text_mod_final)
        
    except :
        pass

# %%
coment_list
# Out:
# ['송강호 유해진 류준열이 한번씩 눈물 쏟게 만듦.. 그날의 광주에 택시운전사와 함께 다녀온 듯 먹먹하다 ',
#  '최근에 본 영화중 가장 돈이 안 아까운 영화! ',
#  '신파일까봐 걱정했는데 신파는 커녕 눈물이 날만하면 가차없이 유쾌함을 던져주던 담백한 영화,,덕분에 억지 눈물이 아닌 진짜 눈물만 나왔다 ',
#  '슬프지만 꼭 한번 봐야 할 영화!권력에 굴복하지 않았던 당당한 시민들과 위르겐 힌츠페터님께 감사드립니다. ',
#  '배우들 연기 때문에 그리고 역사적 상황때문에 넘 마니 울었어요ㅠ가슴이 먹먹하고 뭉클해지실꺼예요 ',
#  '',
#  '우리가 꼭 목격해야 할 1980년 5월의 광주. ',
#  '실컷 웃기더니 더 크게 울림 ',
#  '기다리던영화라 시사회로 보고왔어요. 다루기어려운소재인만큼 마음도 묵직해지는 영화였어요. 꼭봐야할영화로 강추입니다! ',
#  '이번에 시사회 당첨되서 신랑이랑 보러갔는데 영화 끝나고 마음이 먹먹해지면서 엄청 울었네요..귀찮다고 안갔으면 후회할뻔ㅜ올해 한국 영화 중에 천만 찍을거 같아용 기대합니당 ',
#  '송강호 유해진 류준열이 한번씩 눈물 쏟게 만듦.. 그날의 광주에 택시운전사와 함께 다녀온 듯 먹먹하다 ',
#  '최근에 본 영화중 가장 돈이 안 아까운 영화! ',
#  '신파일까봐 걱정했는데 신파는 커녕 눈물이 날만하면 가차없이 유쾌함을 던져주던 담백한 영화,,덕분에 억지 눈물이 아닌 진짜 눈물만 나왔다 ',
#  '슬프지만 꼭 한번 봐야 할 영화!권력에 굴복하지 않았던 당당한 시민들과 위르겐 힌츠페터님께 감사드립니다. ',
#  '배우들 연기 때문에 그리고 역사적 상황때문에 넘 마니 울었어요ㅠ가슴이 먹먹하고 뭉클해지실꺼예요 ',
#  '',
#  '우리가 꼭 목격해야 할 1980년 5월의 광주. ',
#  '실컷 웃기더니 더 크게 울림 ',
#  '기다리던영화라 시사회로 보고왔어요. 다루기어려운소재인만큼 마음도 묵직해지는 영화였어요. 꼭봐야할영화로 강추입니다! ',
# ...

# %%
#저장
import csv

with open('./movie_comment/taxidriver.txt', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(coment_list)
