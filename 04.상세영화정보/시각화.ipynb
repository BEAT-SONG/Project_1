# %%
import pandas as pd

mv = pd.read_csv('./movie_info.csv')
mv_list = pd.read_csv('./total_movie_list_tmp.csv')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
mv
# Out:
#           영화코드               영화명(국문)   상영시간      장르         감독        배우1  \
# 0     20050333                 왕의 남자  119.0     드라마        이준익        감우성
# 1     20050338  나니아 연대기-사자,마녀 그리고 옷장  139.0      가족    앤드류 아담슨      조지 헨리
# 2     20050324                    킹콩  186.0     드라마      피터 잭슨       잭 블랙
# 3     20050326                    태풍  125.0     드라마        곽경택        김혜정
# 4     20050330                작업의 정석  100.0     코미디        오기환        손예진
# ...        ...                   ...    ...     ...        ...        ...
# 3975  20205200   빛의 아버지: 파이널 판타지 XIV  114.0     드라마    노구치 테루오   사카구치 켄타로
# 3976  20200512                미스터 존스  118.0     드라마  아그네츠카 홀란드     제임스 노턴
# 3977  20202666               가을의 마티네  123.0  멜로/로맨스   니시타니 히로시  후쿠야마 마사하루
# 3978  20182674                     걸  105.0     드라마         없음         없음
# 3979  20196672                럭키 몬스터   92.0     드라마        봉준영        김도윤
#
#            배우2      배우3     참여 영화사1         참여 영화사2
# ...

# %%
mv['장르'].value_counts()
# Out:
# 드라마         928
# 애니메이션       671
# 액션          599
# 코미디         377
# 멜로/로맨스      263
# 공포(호러)      211
# 스릴러         175
# 범죄          160
# SF          117
# 다큐멘터리        98
# 미스터리         83
# 판타지          69
# 어드벤처         62
# 사극           48
# 가족           40
# 전쟁           23
# 뮤지컬          19
# 기타           16
# 공연           13
# 없음            5
# 서부극(웨스턴)      3
# Name: 장르, dtype: int64

# %%
mv_list = mv_list.rename(columns={'대표코드':'영화코드'})
mv_list
# Out:
#        Unnamed: 0  순위  순위 증감분 신규진입여부      영화코드               영화명(국문)  \
# 0               0   1       0    OLD  20050333                 왕의 남자
# 1               1   2       0    OLD  20050338  나니아 연대기-사자,마녀 그리고 옷장
# 2               2   3       0    OLD  20050324                    킹콩
# 3               3   4       1    OLD  20050326                    태풍
# 4               4   5      -1    OLD  20050330                작업의 정석
# ...           ...  ..     ...    ...       ...                   ...
# 62085       62085   6       0    OLD  20202647                 나이팅게일
# 62086       62086   7       0    NEW  20202130      빅풋 주니어2: 패밀리가 떴다
# 62087       62087   8       0    OLD  20167904                  라라랜드
# 62088       62088   9       0    OLD  20202128   100% 울프: 푸들이 될 순 없어
# 62089       62089  10       2    OLD  20181983                  이웃사촌
#
#               개봉일         매출액  매출총액 대비 매출비율  전일 대비 매출액 증감분  ...  \
# 0      2005-12-29  1808482000          26.4      654088000  ...
# ...

# %%
mv_name_sum = mv_list.groupby(['영화명(국문)']).sum()
mv_name_sum
# Out:
#                  Unnamed: 0   순위  순위 증감분          매출액  매출총액 대비 매출비율  \
# 영화명(국문)
# #살아있다               2428655  118       4  15947198820        1195.0
# #아이엠히어               433461   28      -6    118604530          58.0
# 0.0MHz               585672   73       4   1015400160          15.2
# 007 노 타임 투 다이       2072072  107      -7  11948538370         823.0
# 007 스카이폴             860047  130      12  17337443500         484.8
# ...                     ...  ...     ...          ...           ...
# 히트맨                 1841431  244      91  21618246900         499.3
# 히트맨 NO.2 : 살인면허       35249   10      39      6906000           0.4
# 히트맨: 에이전트 47         263801   48       1    474744300          12.6
# 힘을 내요, 미스터 리        1043753  113      16   9645685276         148.2
# 힛쳐                    26367   30       1     65091000           1.0
#
#                  전일 대비 매출액 증감분  전일 대비 매출액 증감비율         누적매출액      관객수  \
# 영화명(국문)
# ...

# %%
mv_list.groupby('영화명(국문)').sum(index='관객수')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10764/3419832144.py in <module>
# ----> 1 mv_list.groupby('영화명(국문)').sum(index='관객수')
#
# TypeError: sum() got an unexpected keyword argument 'index'

# %%
mv_name_sum = mv_list.groupby('영화명(국문)')['관객수'].sum()
mv_name_sum
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10764/242871782.py in <module>
# ----> 1 mv_name_sum = mv_list[mv_list.groupby('영화명(국문)')['관객수'].sum()]
#       2 mv_name_sum
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
mv_name_sum
# Out:
# 영화명(국문)
# #살아있다              1900179
# #아이엠히어               14260
# 0.0MHz              128147
# 007 노 타임 투 다이      1222296
# 007 스카이폴           2355557
#                     ...
# 히트맨                2559354
# 히트맨 NO.2 : 살인면허       1048
# 히트맨: 에이전트 47         60731
# 힘을 내요, 미스터 리       1142605
# 힛쳐                    9725
# Name: 관객수, Length: 3891, dtype: int64

# %%
mv_name_sum['장르'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '장르'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mv_list.dtypes
# Out:
# Unnamed: 0           int64
# 순위                   int64
# 순위 증감분               int64
# 신규진입여부              object
# 영화코드                object
# 영화명(국문)             object
# 개봉일                 object
# 매출액                  int64
# 매출총액 대비 매출비율       float64
# 전일 대비 매출액 증감분        int64
# 전일 대비 매출액 증감비율     float64
# 누적매출액                int64
# 관객수                  int64
# 전일 대비 관객수 증감분        int64
# 전일 대비 관객수 증감 비율    float64
# 누적관객수                int64
# 상영 스크린 수             int64
# 상영 횟수                int64
# 년도                   int64
# 날짜                  object
# 월                    int64
# 요일                   int64
# 일자                   int64
# dtype: object

# %%
mv_atd_sum = merge_sum.sort_values('관객수', ascending=False)
mv_atd_sum
# Out:
#                         Unnamed: 0   순위  순위 증감분           매출액  매출총액 대비 매출비율  \
# 영화명(국문)
# 아바타                        4460011  811      48  248763732500        5837.6
# 명량                         2118498  280      41  135474044210        1534.3
# 변호인                        2511980  215      40  123416663500        1994.5
# 극한직업                       3094103  150      11  139410421566        1937.2
# 신과함께-죄와 벌                  3158512  246      10  115601420737        1445.6
# ...                            ...  ...     ...           ...           ...
# 우리, 둘                        59989   10       3       3361740           0.2
# 2007 [통합]영화제/기획전/회고전 등        9259   10      32       2102600           0.2
# 지옥의 묵시록 파이널 컷                55089   10       1       2960500           0.9
# 큰엄마의 미친봉고                    61849   10       6       1428550           0.3
# 그레타 툰베리                      60449   10       0       1218000           0.2
#
# ...

# %%
merge_left_2 = pd.merge(mv_atd_sum, mv, on = '영화명(국문)', how = 'left')
merge_left_2.head(11)
# Out:
#        영화명(국문)  Unnamed: 0   순위  순위 증감분           매출액  매출총액 대비 매출비율  \
# 0          아바타     4460011  811      48  248763732500        5837.6
# 1          아바타     4460011  811      48  248763732500        5837.6
# 2           명량     2118498  280      41  135474044210        1534.3
# 3          변호인     2511980  215      40  123416663500        1994.5
# 4          변호인     2511980  215      40  123416663500        1994.5
# 5         극한직업     3094103  150      11  139410421566        1937.2
# 6    신과함께-죄와 벌     3158512  246      10  115601420737        1445.6
# 7         국제시장     3143521  253      87  110440260330        1763.9
# 8         어벤져스     3070232  366     153  118857088110        2785.4
# 9         어벤져스     3070232  366     153  118857088110        2785.4
# 10  어벤져스: 엔드게임     3495029  284      20  122129020650        1731.9
#
#     전일 대비 매출액 증감분  전일 대비 매출액 증감비율           누적매출액       관객수  ...   상영시간_x  \
# 0       118426500         61555.1  19281901657500  26525581  ...  32844.0
# ...

# %%
genre_cnt = (merge_left_2['장르'].value_counts())
genre_cnt
# Out:
# 드라마         917
# 애니메이션       663
# 액션          590
# 코미디         374
# 멜로/로맨스      260
# 공포(호러)      208
# 스릴러         174
# 범죄          158
# SF          114
# 다큐멘터리        97
# 미스터리         82
# 판타지          67
# 어드벤처         61
# 사극           48
# 가족           40
# 전쟁           23
# 뮤지컬          19
# 기타           16
# 공연           12
# 없음            4
# 서부극(웨스턴)      2
# Name: 장르, dtype: int64

# %%
mv['영화코드'] = mv['영화코드'].apply(str)

# %%
mv_2 = mv.drop(['영화명(국문)'], axis=1)

# %%
mv[mv['영화명(국문)'] == '이웃사촌'].dtypes
# Out:
# 영화코드        object
# 영화명(국문)     object
# 상영시간       float64
# 장르          object
# 감독          object
# 배우1         object
# 배우2         object
# 배우3         object
# 참여 영화사1     object
# 참여 영화사2     object
# dtype: object

# %%
mv_2[mv_2['영화코드'] == '20181983']
# Out:
#           영화코드   상영시간   장르   감독 배우1  배우2  배우3   참여 영화사1    참여 영화사2
# 3420  20181983  130.0  드라마  이환경  정우  오달수  김희원  (주)시네마허브  환타지엔터테인먼트

# %%
mv_2[mv_2['영화'] == '20202647' ].dtypes
# Out:
# 영화코드        object
# 상영시간       float64
# 장르          object
# 감독          object
# 배우1         object
# 배우2         object
# 배우3         object
# 참여 영화사1     object
# 참여 영화사2     object
# dtype: object

# %%
merge_outer = pd.merge(mv_list, mv_2, on= '영화코드', how = 'outer')
merge_outer
# Out:
#        Unnamed: 0   순위  순위 증감분 신규진입여부      영화코드 영화명(국문)         개봉일  \
# 0             0.0  1.0     0.0    OLD  20050333   왕의 남자  2005-12-29
# 1            10.0  1.0     0.0    OLD  20050333   왕의 남자  2005-12-29
# 2            20.0  1.0     0.0    OLD  20050333   왕의 남자  2005-12-29
# 3            30.0  1.0    10.0    OLD  20050333   왕의 남자  2005-12-29
# 4          6438.0  9.0     0.0    OLD  20050333   왕의 남자  2005-12-29
# ...           ...  ...     ...    ...       ...     ...         ...
# 65443         NaN  NaN     NaN    NaN  20205200     NaN         NaN
# 65444         NaN  NaN     NaN    NaN  20200512     NaN         NaN
# 65445         NaN  NaN     NaN    NaN  20202666     NaN         NaN
# 65446         NaN  NaN     NaN    NaN  20182674     NaN         NaN
# 65447         NaN  NaN     NaN    NaN  20196672     NaN         NaN
#
#                 매출액  매출총액 대비 매출비율  전일 대비 매출액 증감분  ...   요일    일자   상영시간  \
# 0      1.808482e+09          26.4    654088000.0  ...  5.0  31.0  119.0
# ...

# %%
merge_outer[merge_outer['영화코드'] == '20202647' ]
# Out:
#        Unnamed: 0  순위  순위 증감분 신규진입여부      영화코드 영화명(국문)  개봉일  매출액  \
# 64895         NaN NaN     NaN    NaN  20202647     NaN  NaN  NaN
#
#        매출총액 대비 매출비율  전일 대비 매출액 증감분  ...  요일  일자   상영시간   장르      감독     배우1  \
# 64895           NaN            NaN  ... NaN NaN  136.0  스릴러  제니퍼 켄트  샘 클라플린
#
#        배우2  배우3       참여 영화사1    참여 영화사2
# 64895   없음   없음  (주)제이앤씨미디어그룹  (유)조이앤시네마
#
# [1 rows x 31 columns]

# %%
merge_left = pd.merge(mv_list, mv_2, on= '영화코드', how = 'left')
merge_left
# Out:
#        Unnamed: 0  순위  순위 증감분 신규진입여부      영화코드               영화명(국문)  \
# 0               0   1       0    OLD  20050333                 왕의 남자
# 1               1   2       0    OLD  20050338  나니아 연대기-사자,마녀 그리고 옷장
# 2               2   3       0    OLD  20050324                    킹콩
# 3               3   4       1    OLD  20050326                    태풍
# 4               4   5      -1    OLD  20050330                작업의 정석
# ...           ...  ..     ...    ...       ...                   ...
# 63350       62085   6       0    OLD  20202647                 나이팅게일
# 63351       62086   7       0    NEW  20202130      빅풋 주니어2: 패밀리가 떴다
# 63352       62087   8       0    OLD  20167904                  라라랜드
# 63353       62088   9       0    OLD  20202128   100% 울프: 푸들이 될 순 없어
# 63354       62089  10       2    OLD  20181983                  이웃사촌
#
#               개봉일         매출액  매출총액 대비 매출비율  전일 대비 매출액 증감분  ...  요일  일자  \
# ...

# %%
merge_left[merge_left['영화코드'] == '20202647' ]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 순위, 순위 증감분, 신규진입여부, 영화코드, 영화명(국문), 개봉일, 매출액, 매출총액 대비 매출비율, 전일 대비 매출액 증감분, 전일 대비 매출액 증감비율, 누적매출액, 관객수, 전일 대비 관객수 증감분, 전일 대비 관객수 증감 비율, 누적관객수, 상영 스크린 수, 상영 횟수, 년도, 날짜, 월, 요일, 일자, 상영시간, 장르, 감독, 배우1, 배우2, 배우3, 참여 영화사1, 참여 영화사2]
# Index: []
#
# [0 rows x 31 columns]

# %%
mv_new = mv_list.set_index('영화코드').join(mv_2.set_index('영화코드'))
mv_new
# Out:
#           Unnamed: 0  순위  순위 증감분 신규진입여부  영화명(국문)         개봉일        매출액  \
# 영화코드
# 19548002       35139  10       7    OLD     사브리나                1140000
# 19720061       50267   8       0    NEW      정무문  1973-07-27   26872000
# 19818004       41828   9      10    OLD    불의 전차  2016-06-16   12462000
# 19880001       53048   9       1    OLD  이웃집 토토로  2001-07-28   19519880
# 19880001       53059  10       1    OLD  이웃집 토토로  2001-07-28   18613660
# ...              ...  ..     ...    ...      ...         ...        ...
# 20139981       29325   6      -1    OLD      캐치미  2013-12-18  578771000
# 20139981       29334   5       0    OLD      캐치미  2013-12-18  366778500
# 20139981       29344   5       0    OLD      캐치미  2013-12-18  311917500
# 20139981       29354   5      26    OLD      캐치미  2013-12-18  199920500
# 20139981       29378   9      29    OLD      캐치미  2013-12-18   14200000
#
#           매출총액 대비 매출비율  전일 대비 매출액 증감분  전일 대비 매출액 증감비율  ...  요일  일자   상영시간  \
# ...

# %%
merge_left.tail(30)
# Out:
#        Unnamed: 0  순위  순위 증감분 신규진입여부      영화코드              영화명(국문)  \
# 63325       62060   1       0    OLD  20192567           원더 우먼 1984
# 63326       62061   2       0    OLD  20040725                 화양연화
# 63327       62062   3       0    OLD  20202703                  뱅가드
# 63328       62063   4       0    OLD  20201002                   조제
# 63329       62064   5       0    OLD  20192193                   도굴
# 63330       62065   6       0    OLD  20202647                나이팅게일
# 63331       62066   7       0    OLD  20202130     빅풋 주니어2: 패밀리가 떴다
# 63332       62067   8       0    OLD  20167904                 라라랜드
# 63333       62068   9       0    OLD  20081445                  굿바이
# 63334       62069  10       1    OLD  20181983                 이웃사촌
# 63335       62070   1       0    OLD  20192567           원더 우먼 1984
# 63336       62071   2       1    OLD  20040725                 화양연화
# 63337       62072   3      -1    OLD  20202703                  뱅가드
# ...

# %%
mv_list
# Out:
#        Unnamed: 0  순위  순위 증감분 신규진입여부      영화코드               영화명(국문)  \
# 0               0   1       0    OLD  20050333                 왕의 남자
# 1               1   2       0    OLD  20050338  나니아 연대기-사자,마녀 그리고 옷장
# 2               2   3       0    OLD  20050324                    킹콩
# 3               3   4       1    OLD  20050326                    태풍
# 4               4   5      -1    OLD  20050330                작업의 정석
# ...           ...  ..     ...    ...       ...                   ...
# 62085       62085   6       0    OLD  20202647                 나이팅게일
# 62086       62086   7       0    NEW  20202130      빅풋 주니어2: 패밀리가 떴다
# 62087       62087   8       0    OLD  20167904                  라라랜드
# 62088       62088   9       0    OLD  20202128   100% 울프: 푸들이 될 순 없어
# 62089       62089  10       2    OLD  20181983                  이웃사촌
#
#               개봉일         매출액  매출총액 대비 매출비율  전일 대비 매출액 증감분  ...  \
# 0      2005-12-29  1808482000          26.4      654088000  ...
# ...

# %%
merge_right = pd.merge(mv_list, mv, on= '영화코드', how = 'right')
merge_right
# Out:
#        Unnamed: 0   순위  순위 증감분 신규진입여부      영화코드 영화명(국문)_x         개봉일  \
# 0             0.0  1.0     0.0    OLD  20050333     왕의 남자  2005-12-29
# 1            10.0  1.0     0.0    OLD  20050333     왕의 남자  2005-12-29
# 2            20.0  1.0     0.0    OLD  20050333     왕의 남자  2005-12-29
# 3            30.0  1.0    10.0    OLD  20050333     왕의 남자  2005-12-29
# 4          6438.0  9.0     0.0    OLD  20050333     왕의 남자  2005-12-29
# ...           ...  ...     ...    ...       ...       ...         ...
# 36097         NaN  NaN     NaN    NaN  20205200       NaN         NaN
# 36098         NaN  NaN     NaN    NaN  20200512       NaN         NaN
# 36099         NaN  NaN     NaN    NaN  20202666       NaN         NaN
# 36100         NaN  NaN     NaN    NaN  20182674       NaN         NaN
# 36101         NaN  NaN     NaN    NaN  20196672       NaN         NaN
#
#                 매출액  매출총액 대비 매출비율  전일 대비 매출액 증감분  ...    일자  \
# 0      1.808482e+09          26.4    654088000.0  ...  31.0
# ...

# %%
merge_2 = merge_left.groupby(['영화명(국문)']).sum()
merge_2
# Out:
#                  Unnamed: 0   순위  순위 증감분          매출액  매출총액 대비 매출비율  \
# 영화명(국문)
# #살아있다               2428655  118       4  15947198820        1195.0
# #아이엠히어               433461   28      -6    118604530          58.0
# 0.0MHz               585672   73       4   1015400160          15.2
# 007 노 타임 투 다이       2072072  107      -7  11948538370         823.0
# 007 스카이폴             860047  130      12  17337443500         484.8
# ...                     ...  ...     ...          ...           ...
# 히트맨                 1841431  244      91  21618246900         499.3
# 히트맨 NO.2 : 살인면허       35249   10      39      6906000           0.4
# 히트맨: 에이전트 47         263801   48       1    474744300          12.6
# 힘을 내요, 미스터 리        1043753  113      16   9645685276         148.2
# 힛쳐                    26367   30       1     65091000           1.0
#
#                  전일 대비 매출액 증감분  전일 대비 매출액 증감비율         누적매출액      관객수  \
# 영화명(국문)
# ...

# %%
merge_sum = merge_2.sum()
merge_sum
# Out:
#                  Unnamed: 0   순위  순위 증감분          매출액  매출총액 대비 매출비율  \
# 영화명(국문)
# #살아있다               2428655  118       4  15947198820        1195.0
# #아이엠히어               433461   28      -6    118604530          58.0
# 0.0MHz               585672   73       4   1015400160          15.2
# 007 노 타임 투 다이       2072072  107      -7  11948538370         823.0
# 007 스카이폴             860047  130      12  17337443500         484.8
# ...                     ...  ...     ...          ...           ...
# 히트맨                 1841431  244      91  21618246900         499.3
# 히트맨 NO.2 : 살인면허       35249   10      39      6906000           0.4
# 히트맨: 에이전트 47         263801   48       1    474744300          12.6
# 힘을 내요, 미스터 리        1043753  113      16   9645685276         148.2
# 힛쳐                    26367   30       1     65091000           1.0
#
#                  전일 대비 매출액 증감분  전일 대비 매출액 증감비율         누적매출액      관객수  \
# 영화명(국문)
# ...

# %%
merge_atd_sum = merge_sum.sort_values('누적관객수', ascending=False)

# %%
merge_atd_sum.head(10)
# Out:
#              Unnamed: 0   순위  순위 증감분           매출액  매출총액 대비 매출비율  \
# 영화명(국문)
# 아바타             4460011  811      48  248763732500        5837.6
# 알라딘             6274316  403       1  107683031449        1858.0
# 광해, 왕이 된 남자     2565265  363      10   88604681769        2336.4
# 국제시장            3143521  253      87  110440260330        1763.9
# 어벤져스: 엔드게임      3495029  284      20  122129020650        1731.9
# 기생충             4885336  436      29   86963603405        1318.7
# 명량              2118498  280      41  135474044210        1534.3
# 7번방의 선물         2645920  292      22   91321831670        1796.9
# 베테랑             2825549  254      23  105027419150        1664.2
# 신과함께-죄와 벌       3158512  246      10  115601420737        1445.6
#
#              전일 대비 매출액 증감분  전일 대비 매출액 증감비율           누적매출액       관객수  \
# 영화명(국문)
# 아바타              118426500         61555.1  19281901657500  26525581
# 알라딘                7654420          5995.4   8947350706636  12669887
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
import platform

# %%
fig = plt.figure(figsize = (25, 10))
sns.barplot(data=genre_cnt)
plt.title("시간대별 승객구분별 버스내 체류시간(분) 분석")
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49849 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
